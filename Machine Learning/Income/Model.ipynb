# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('canada_per_capita_income.csv')

# %%
df.head(3)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('Per capita income (US $)')
plt.scatter(df['year'], df['per capita income (US$)'], color='red', marker='+')

# %%
X = df[['year']]
Y = df['per capita income (US$)']
reg = LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
inputYear = int(input("Enter the year after 2016 for which you want the predicted income):"))
output = reg.predict([[inputYear]])
output
# Out:
# c:\Users\Aditya Aryan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
df1 = df.copy()
df1.to_csv('NewPrediction.csv', index=False)

# %%
df1.head(4)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248

# %%
newInput = {
    "year": inputYear,
    "per capita income (US$)": Output
}

# %%
df1 = pd.read_csv('NewPrediction.csv')

# %%
df1 = df1.append(newInput, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12700\1867355870.py in ?()
# ----> 1 df1 = df1.append(newInput, ignore_index=True)
#
# c:\Users\Aditya Aryan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
